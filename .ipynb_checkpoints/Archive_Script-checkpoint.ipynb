# %%
import functions

# %%
from archapp.interactive import EpicsArchive

# %% [markdown]
# - Create an object calling the EpicsArchive class in interactive.py
#
# - Get data for a PV by using get function in EpicsArchive
#     data = object_name.get("pv_name" or ["pv1","pv2",..."pvn"],
#     xarray=True)
#   data is returned in xarray
#   Look at interactive.py for function arguements
#
# - NOTE: values in sevr and stat are indicies in the sevr_enum list and stat_enum list in epics.py

# %%
arch = EpicsArchive()

# %%
data = arch.stats(['MIRR:FEE1:M2H:VAL', 'MIRR:FEE1:M2H:RBV'])
# Out:
# How many minutes? 1
# Mirror Position should be:  121.0
# Mean of Mirror Position:    120.982
# Mean of Deviation:          0.018
# Standard Deviation:         0.028
# Mirror Position should be:  121.0
# Mean of Mirror Position:    121.004
# Mean of Deviation:          -0.004
# Standard Deviation:         0.028
# Mirror Position should be:  121.0
# Mean of Mirror Position:    120.993
# Mean of Deviation:          0.007
# Standard Deviation:         0.02
# Mirror Position should be:  121.0
# Mean of Mirror Position:    120.997
# Mean of Deviation:          0.003
# Standard Deviation:         0.033
# Mirror Position should be:  121.0
# Mean of Mirror Position:    121.013
# Mean of Deviation:          -0.013
# Standard Deviation:         0.023
# Mirror Position should be:  121.0
# Mean of Mirror Position:    120.994
# Mean of Deviation:          0.006
# Standard Deviation:         0.038
